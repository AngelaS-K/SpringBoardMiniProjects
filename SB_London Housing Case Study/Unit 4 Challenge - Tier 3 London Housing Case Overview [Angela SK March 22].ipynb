# %% [markdown]
# # Springboard Data Science Career Track Unit 4 Challenge - Tier 3 Complete
#
# ## Objectives
# Hey! Great job getting through those challenging DataCamp courses. You're learning a lot in a short span of time.
#
# In this notebook, you're going to apply the skills you've been learning, bridging the gap between the controlled environment of DataCamp and the *slightly* messier work that data scientists do with actual datasets!
#
# Here’s the mystery we’re going to solve: ***which boroughs of London have seen the greatest increase in housing prices, on average, over the last two decades?***
#
#
# A borough is just a fancy word for district. You may be familiar with the five boroughs of New York… well, there are 32 boroughs within Greater London [(here's some info for the curious)](https://en.wikipedia.org/wiki/London_boroughs). Some of them are more desirable areas to live in, and the data will reflect that with a greater rise in housing prices.
#
# ***This is the Tier 3 notebook, which means it's not filled in at all: we'll just give you the skeleton of a project, the brief and the data. It's up to you to play around with it and see what you can find out! Good luck! If you struggle, feel free to look at easier tiers for help; but try to dip in and out of them, as the more independent work you do, the better it is for your learning!***
#
# This challenge will make use of only what you learned in the following DataCamp courses:
# - Prework courses (Introduction to Python for Data Science, Intermediate Python for Data Science)
# - Data Types for Data Science
# - Python Data Science Toolbox (Part One)
# - pandas Foundations
# - Manipulating DataFrames with pandas
# - Merging DataFrames with pandas
#
# Of the tools, techniques and concepts in the above DataCamp courses, this challenge should require the application of the following:
# - **pandas**
#     - **data ingestion and inspection** (pandas Foundations, Module One)
#     - **exploratory data analysis** (pandas Foundations, Module Two)
#     - **tidying and cleaning** (Manipulating DataFrames with pandas, Module Three)
#     - **transforming DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **subsetting DataFrames with lists** (Manipulating DataFrames with pandas, Module One)
#     - **filtering DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **grouping data** (Manipulating DataFrames with pandas, Module Four)
#     - **melting data** (Manipulating DataFrames with pandas, Module Three)
#     - **advanced indexing** (Manipulating DataFrames with pandas, Module Four)
# - **matplotlib** (Intermediate Python for Data Science, Module One)
# - **fundamental data types** (Data Types for Data Science, Module One)
# - **dictionaries** (Intermediate Python for Data Science, Module Two)
# - **handling dates and times** (Data Types for Data Science, Module Four)
# - **function definition** (Python Data Science Toolbox - Part One, Module One)
# - **default arguments, variable length, and scope** (Python Data Science Toolbox - Part One, Module Two)
# - **lambda functions and error handling** (Python Data Science Toolbox - Part One, Module Four)

# %% [markdown]
# ## The Data Science Pipeline
#
# This is Tier Three, so we'll get you started. But after that, it's all in your hands! When you feel done with your investigations, look back over what you've accomplished, and prepare a quick presentation of your findings for the next mentor meeting.
#
# Data Science is magical. In this case study, you'll get to apply some complex machine learning algorithms. But as  [David Spiegelhalter](https://www.youtube.com/watch?v=oUs1uvsz0Ok) reminds us, there is no substitute for simply **taking a really, really good look at the data.** Sometimes, this is all we need to answer our question.
#
# Data Science projects generally adhere to the four stages of Data Science Pipeline:
# 1. Sourcing and loading
# 2. Cleaning, transforming, and visualizing
# 3. Modeling
# 4. Evaluating and concluding

# %% [markdown]
# ### 1. Sourcing and Loading
#
# Any Data Science project kicks off by importing  ***pandas***. The documentation of this wonderful library can be found [here](https://pandas.pydata.org/). As you've seen, pandas is conveniently connected to the [Numpy](http://www.numpy.org/) and [Matplotlib](https://matplotlib.org/) libraries.
#
# ***Hint:*** This part of the data science pipeline will test those skills you acquired in the pandas Foundations course, Module One.

# %% [markdown]
# #### 1.1. Importing Libraries

# %%
# Let's import the pandas, numpy libraries as pd, and np respectively. 
import pandas as pd
import numpy as np

# Load the pyplot collection of functions from matplotlib, as plt 
import matplotlib.pyplot as plt

# %% [markdown]
# #### 1.2.  Loading the data
# Your data comes from the [London Datastore](https://data.london.gov.uk/): a free, open-source data-sharing portal for London-oriented datasets.

# %%
# First, make a variable called url_LondonHousePrices, and assign it the following link, enclosed in quotation-marks as a string:
# https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls

url_LondonHousePrices = "https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls"

# The dataset we're interested in contains the Average prices of the houses, and is actually on a particular sheet of the Excel file. 
# As a result, we need to specify the sheet name in the read_excel() method.
# Put this data into a variable called properties.  
properties = pd.read_excel(url_LondonHousePrices, sheet_name='Average price', index_col= None)

# %% [markdown]
# ### 2. Cleaning, transforming, and visualizing
# This second stage is arguably the most important part of any Data Science project. The first thing to do is take a proper look at the data. Cleaning forms the majority of this stage, and can be done both before or after Transformation.
#
# The end goal of data cleaning is to have tidy data. When data is tidy:
#
# 1. Each variable has a column.
# 2. Each observation forms a row.
#
# Keep the end goal in mind as you move through this process, every step will take you closer.
#
#
#
# ***Hint:*** This part of the data science pipeline should test those skills you acquired in:
# - Intermediate Python for data science, all modules.
# - pandas Foundations, all modules.
# - Manipulating DataFrames with pandas, all modules.
# - Data Types for Data Science, Module Four.
# - Python Data Science Toolbox - Part One, all modules

# %% [markdown]
# **2.1. Exploring your data**
#
# Think about your pandas functions for checking out a dataframe.

# %%
#to check the number of rows and columns
properties.shape
# Out:
# (329, 49)

# %%
properties.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 329 entries, 0 to 328
# Data columns (total 49 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            328 non-null    datetime64[ns]
#  1   City of London        329 non-null    object
#  2   Barking & Dagenham    329 non-null    object
#  3   Barnet                329 non-null    object
#  4   Bexley                329 non-null    object
#  5   Brent                 329 non-null    object
#  6   Bromley               329 non-null    object
#  7   Camden                329 non-null    object
#  8   Croydon               329 non-null    object
#  9   Ealing                329 non-null    object
#  10  Enfield               329 non-null    object
#  11  Greenwich             329 non-null    object
#  12  Hackney               329 non-null    object
#  13  Hammersmith & Fulham  329 non-null    object
# ...

# %%
#checking few rows of the dataframe
properties.head()
# Out:
#   Unnamed: 0 City of London Barking & Dagenham       Barnet       Bexley  \
# 0        NaT      E09000001          E09000002    E09000003    E09000004
# 1 1995-01-01    91448.98487         50460.2266  93284.51832  64958.09036
# 2 1995-02-01    82202.77314        51085.77983  93190.16963  64787.92069
# 3 1995-03-01    79120.70256        51268.96956  92247.52435  64367.49344
# 4 1995-04-01    77101.20804        53133.50526  90762.87492  64277.66881
#
#          Brent      Bromley       Camden      Croydon       Ealing  ...  \
# 0    E09000005    E09000006    E09000007    E09000008    E09000009  ...
# 1  71306.56698  81671.47692  120932.8881  69158.16225  79885.89069  ...
# 2  72022.26197  81657.55944  119508.8622  68951.09542  80897.06551  ...
# 3  72015.76274  81449.31143  120282.2131  68712.44341  81379.86288  ...
# 4  72965.63094  81124.41227   120097.899  68610.04641  82188.90498  ...
#
#     NORTH WEST YORKS & THE HUMBER EAST MIDLANDS WEST MIDLANDS EAST OF ENGLAND  \
# ...

# %% [markdown]
# **2.2. Cleaning the data**
#
# You might find you need to transpose your dataframe, check out what its row indexes are, and reset the index. You  also might find you need to assign the values of the first row to your column headings  . (Hint: recall the .columns feature of DataFrames, as well as the iloc[] method).
#
# Don't be afraid to use StackOverflow for help  with this.

# %%
properties_1 = properties.T

# %%
properties_1.head()
# Out:
#                           0                    1                    2    \
# Unnamed: 0                NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# City of London      E09000001          91448.98487          82202.77314
# Barking & Dagenham  E09000002           50460.2266          51085.77983
# Barnet              E09000003          93284.51832          93190.16963
# Bexley              E09000004          64958.09036          64787.92069
#
#                                     3                    4    \
# Unnamed: 0          1995-03-01 00:00:00  1995-04-01 00:00:00
# City of London              79120.70256          77101.20804
# Barking & Dagenham          51268.96956          53133.50526
# Barnet                      92247.52435          90762.87492
# Bexley                      64367.49344          64277.66881
#
#                                     5                    6    \
# Unnamed: 0          1995-05-01 00:00:00  1995-06-01 00:00:00
# ...

# %%
properties_1.index
# Out:
# Index(['Unnamed: 0', 'City of London', 'Barking & Dagenham', 'Barnet',
#        'Bexley', 'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey', 'Harrow',
#        'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth', 'Lewisham',
#        'Merton', 'Newham', 'Redbridge', 'Richmond upon Thames', 'Southwark',
#        'Sutton', 'Tower Hamlets', 'Waltham Forest', 'Wandsworth',
#        'Westminster', 'Unnamed: 34', 'Inner London', 'Outer London',
#        'Unnamed: 37', 'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER',
#        'EAST MIDLANDS', 'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON',
#        'SOUTH EAST', 'SOUTH WEST', 'Unnamed: 47', 'England'],
#       dtype='object')

# %%
properties_2 = properties_1.reset_index()

# %%
properties_2.head()
# Out:
#                 index          0                    1                    2  \
# 0          Unnamed: 0        NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# 1      City of London  E09000001          91448.98487          82202.77314
# 2  Barking & Dagenham  E09000002           50460.2266          51085.77983
# 3              Barnet  E09000003          93284.51832          93190.16963
# 4              Bexley  E09000004          64958.09036          64787.92069
#
#                      3                    4                    5  \
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00
# 1          79120.70256          77101.20804          84409.14932
# 2          51268.96956          53133.50526          53042.24852
# 3          92247.52435          90762.87492          90258.00033
# 4          64367.49344          64277.66881          63997.13588
#
#                      6                    7                    8  ...  \
# ...

# %%
header = properties_2["index"]

# %%
print(header)
# Out:
# 0               Unnamed: 0
# 1           City of London
# 2       Barking & Dagenham
# 3                   Barnet
# 4                   Bexley
# 5                    Brent
# 6                  Bromley
# 7                   Camden
# 8                  Croydon
# 9                   Ealing
# 10                 Enfield
# 11               Greenwich
# 12                 Hackney
# 13    Hammersmith & Fulham
# 14                Haringey
# 15                  Harrow
# 16                Havering
# 17              Hillingdon
# 18                Hounslow
# 19               Islington
# 20    Kensington & Chelsea
# 21    Kingston upon Thames
# 22                 Lambeth
# 23                Lewisham
# 24                  Merton
# 25                  Newham
# 26               Redbridge
# 27    Richmond upon Thames
# 28               Southwark
# 29                  Sutton
# 30           Tower Hamlets
# 31          Waltham Forest
# 32              Wandsworth
# 33             Westminster
# ...

# %%
properties_2.columns
# Out:
# Index(['index',       0,       1,       2,       3,       4,       5,       6,
#              7,       8,
#        ...
#            319,     320,     321,     322,     323,     324,     325,     326,
#            327,     328],
#       dtype='object', length=330)

# %%
properties_2.columns = properties_2.loc[0,:]

# %%
properties_2.head()
# Out:
# 0          Unnamed: 0        NaN  1995-01-01 00:00:00  1995-02-01 00:00:00  \
# 0          Unnamed: 0        NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# 1      City of London  E09000001          91448.98487          82202.77314
# 2  Barking & Dagenham  E09000002           50460.2266          51085.77983
# 3              Barnet  E09000003          93284.51832          93190.16963
# 4              Bexley  E09000004          64958.09036          64787.92069
#
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00  \
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00
# 1          79120.70256          77101.20804          84409.14932
# 2          51268.96956          53133.50526          53042.24852
# 3          92247.52435          90762.87492          90258.00033
# 4          64367.49344          64277.66881          63997.13588
#
# 0  1995-06-01 00:00:00  1995-07-01 00:00:00  1995-08-01 00:00:00  ...  \
# ...

# %%
properties_3 = properties_2.drop(0)

# %%
properties_3.head()
# Out:
# 0          Unnamed: 0        NaN 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 1      City of London  E09000001         91448.98487         82202.77314
# 2  Barking & Dagenham  E09000002          50460.2266         51085.77983
# 3              Barnet  E09000003         93284.51832         93190.16963
# 4              Bexley  E09000004         64958.09036         64787.92069
# 5               Brent  E09000005         71306.56698         72022.26197
#
# 0 1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 1         79120.70256         77101.20804         84409.14932
# 2         51268.96956         53133.50526         53042.24852
# 3         92247.52435         90762.87492         90258.00033
# 4         64367.49344         64277.66881         63997.13588
# 5         72015.76274         72965.63094         73704.04743
#
# 0 1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  ...  \
# 1         94900.51244         110128.0423         112329.4376  ...
# ...

# %% [markdown]
# **2.3. Cleaning the data (part 2)**
#
# You might we have to **rename** a couple columns. How do you do this? The clue's pretty bold...

# %%
properties_4 = properties_3.rename(columns = {'Unnamed: 0':'London_Borough', pd.NaT: 'ID'})

# %%
properties_4.head()
# Out:
# 0      London_Borough         ID 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 1      City of London  E09000001         91448.98487         82202.77314
# 2  Barking & Dagenham  E09000002          50460.2266         51085.77983
# 3              Barnet  E09000003         93284.51832         93190.16963
# 4              Bexley  E09000004         64958.09036         64787.92069
# 5               Brent  E09000005         71306.56698         72022.26197
#
# 0 1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 1         79120.70256         77101.20804         84409.14932
# 2         51268.96956         53133.50526         53042.24852
# 3         92247.52435         90762.87492         90258.00033
# 4         64367.49344         64277.66881         63997.13588
# 5         72015.76274         72965.63094         73704.04743
#
# 0 1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  ...  \
# 1         94900.51244         110128.0423         112329.4376  ...
# ...

# %% [markdown]
# **2.4.Transforming the data**
#
# Remember what Wes McKinney said about tidy data?
#
# You might need to **melt** your DataFrame here.

# %%
properties_4.columns
# Out:
# Index([   'London_Borough',                'ID', 1995-01-01 00:00:00,
#        1995-02-01 00:00:00, 1995-03-01 00:00:00, 1995-04-01 00:00:00,
#        1995-05-01 00:00:00, 1995-06-01 00:00:00, 1995-07-01 00:00:00,
#        1995-08-01 00:00:00,
#        ...
#        2021-07-01 00:00:00, 2021-08-01 00:00:00, 2021-09-01 00:00:00,
#        2021-10-01 00:00:00, 2021-11-01 00:00:00, 2021-12-01 00:00:00,
#        2022-01-01 00:00:00, 2022-02-01 00:00:00, 2022-03-01 00:00:00,
#        2022-04-01 00:00:00],
#       dtype='object', name=0, length=330)

# %%
properties_5 = pd.melt(properties_4, id_vars= ['London_Borough', 'ID'])

# %%
properties_5.head()
# Out:
#        London_Borough         ID          0        value
# 0      City of London  E09000001 1995-01-01  91448.98487
# 1  Barking & Dagenham  E09000002 1995-01-01   50460.2266
# 2              Barnet  E09000003 1995-01-01  93284.51832
# 3              Bexley  E09000004 1995-01-01  64958.09036
# 4               Brent  E09000005 1995-01-01  71306.56698

# %%
properties_6 = properties_5.rename(columns = {0: 'Month', 'value': 'Average_price'})

# %%
properties_6.head()
# Out:
#        London_Borough         ID      Month Average_price
# 0      City of London  E09000001 1995-01-01   91448.98487
# 1  Barking & Dagenham  E09000002 1995-01-01    50460.2266
# 2              Barnet  E09000003 1995-01-01   93284.51832
# 3              Bexley  E09000004 1995-01-01   64958.09036
# 4               Brent  E09000005 1995-01-01   71306.56698

# %% [markdown]
# Remember to make sure your column data types are all correct. Average prices, for example, should be floating point numbers...

# %%
properties_6.dtypes
# Out:
# London_Borough            object
# ID                        object
# Month             datetime64[ns]
# Average_price             object
# dtype: object

# %%
properties_6['Average_price'] = pd.to_numeric(properties_6['Average_price'])

# %%
sum(properties_6['Average_price'] == '-')
# Out:
# 0

# %%
properties_6 = properties_6[properties_6['Average_price'] != '-']

# %%
properties_6['Average_price'] = pd.to_numeric(properties_6['Average_price'])

# %%
properties_6.dtypes
# Out:
# London_Borough            object
# ID                        object
# Month             datetime64[ns]
# Average_price            float64
# dtype: object

# %%
properties_6.count()
# Out:
# London_Borough    15744
# ID                14760
# Month             15744
# Average_price     14760
# dtype: int64

# %% [markdown]
# **2.5. Cleaning the data (part 3)**
#
# Do we have an equal number of observations in the ID, Average Price, Month, and London Borough columns? Remember that there are only 32 London Boroughs. How many entries do you have in that column?
#
# Check out the contents of the London Borough column, and if you find null values, get rid of them however you see fit.

# %%
pd.value_counts(properties_6['London_Borough'])
# Out:
# Lewisham                328
# Bexley                  328
# Outer London            328
# Barking & Dagenham      328
# Croydon                 328
# Hammersmith & Fulham    328
# Westminster             328
# Southwark               328
# Haringey                328
# Wandsworth              328
# Lambeth                 328
# Waltham Forest          328
# Hounslow                328
# EAST MIDLANDS           328
# Unnamed: 34             328
# Islington               328
# SOUTH EAST              328
# City of London          328
# Enfield                 328
# Redbridge               328
# Kingston upon Thames    328
# England                 328
# Newham                  328
# Unnamed: 37             328
# Havering                328
# Kensington & Chelsea    328
# NORTH EAST              328
# Ealing                  328
# Merton                  328
# Greenwich               328
# Harrow                  328
# Brent                   328
# WEST MIDLANDS           328
# ...

# %%
properties_6[properties_6['London_Borough'] == 'Unnamed: 34'].head()
# Out:
#     London_Borough   ID      Month  Average_price
# 33     Unnamed: 34  NaN 1995-01-01            NaN
# 81     Unnamed: 34  NaN 1995-02-01            NaN
# 129    Unnamed: 34  NaN 1995-03-01            NaN
# 177    Unnamed: 34  NaN 1995-04-01            NaN
# 225    Unnamed: 34  NaN 1995-05-01            NaN

# %%
properties_6[properties_6['London_Borough'] == 'Unnamed: 37'].head()
# Out:
#     London_Borough   ID      Month  Average_price
# 36     Unnamed: 37  NaN 1995-01-01            NaN
# 84     Unnamed: 37  NaN 1995-02-01            NaN
# 132    Unnamed: 37  NaN 1995-03-01            NaN
# 180    Unnamed: 37  NaN 1995-04-01            NaN
# 228    Unnamed: 37  NaN 1995-05-01            NaN

# %%
properties_6[properties_6['London_Borough'] == 'Unnamed: 47'].head()
# Out:
#     London_Borough   ID      Month  Average_price
# 46     Unnamed: 47  NaN 1995-01-01            NaN
# 94     Unnamed: 47  NaN 1995-02-01            NaN
# 142    Unnamed: 47  NaN 1995-03-01            NaN
# 190    Unnamed: 47  NaN 1995-04-01            NaN
# 238    Unnamed: 47  NaN 1995-05-01            NaN

# %%
properties_7 = properties_6[~properties_6['London_Borough'].str.startswith('Unnamed')]

# %%
pd.value_counts(properties_7['London_Borough'])
# Out:
# Lewisham                328
# Havering                328
# Barking & Dagenham      328
# Croydon                 328
# Hammersmith & Fulham    328
# Westminster             328
# Southwark               328
# Haringey                328
# Wandsworth              328
# Lambeth                 328
# Waltham Forest          328
# Hounslow                328
# EAST MIDLANDS           328
# Islington               328
# SOUTH EAST              328
# City of London          328
# Enfield                 328
# Redbridge               328
# Kingston upon Thames    328
# England                 328
# Newham                  328
# Outer London            328
# Kensington & Chelsea    328
# Bexley                  328
# EAST OF ENGLAND         328
# Ealing                  328
# Merton                  328
# Greenwich               328
# Harrow                  328
# Brent                   328
# WEST MIDLANDS           328
# SOUTH WEST              328
# Inner London            328
# ...

# %%
properties_7[properties_7['ID'].isna()]
# Out:
# Empty DataFrame
# Columns: [London_Borough, ID, Month, Average_price]
# Index: []

# %%
properties_7[properties_7['Average_price'].isna()]
# Out:
# Empty DataFrame
# Columns: [London_Borough, ID, Month, Average_price]
# Index: []

# %%
properties_7[properties_7['Month'].isna()]
# Out:
# Empty DataFrame
# Columns: [London_Borough, ID, Month, Average_price]
# Index: []

# %%
sum(properties_7['Average_price'].isna())
# Out:
# 0

# %%
properties_7.isna().sum()
# Out:
# London_Borough    0
# ID                0
# Month             0
# Average_price     0
# dtype: int64

# %%
properties_5.shape
# Out:
# (15744, 4)

# %%
properties_7.shape
# Out:
# (14760, 4)

# %% [markdown]
# Removing three of the unnamed rows has deleted 966 rows.
# and 0 null(NaN) values left.

# %%
nonBoroughs = ['Inner London', 'Outer London', 'NORTH EAST','NORTH WEST', 'YORKS & THE HUMBER', 'EAST MIDLANDS', 'WEST MIDLANDS','EAST OF ENGLAND', 'LONDON', 'SOUTH EAST','SOUTH WEST', 'England']

# %%
properties_7[properties_7.London_Borough.isin(nonBoroughs)]
# Out:
#            London_Borough         ID      Month  Average_price
# 34           Inner London  E13000001 1995-01-01    78251.97650
# 35           Outer London  E13000002 1995-01-01    72958.79836
# 37             NORTH EAST  E12000001 1995-01-01    42076.35411
# 38             NORTH WEST  E12000002 1995-01-01    43958.48001
# 39     YORKS & THE HUMBER  E12000003 1995-01-01    44803.42878
# ...                   ...        ...        ...            ...
# 15738     EAST OF ENGLAND  E12000006 2022-04-01   344942.95540
# 15739              LONDON  E12000007 2022-04-01   529828.59810
# 15740          SOUTH EAST  E12000008 2022-04-01   382790.78500
# 15741          SOUTH WEST  E12000009 2022-04-01   318610.43760
# 15743             England  E92000001 2022-04-01   299249.03100
#
# [3936 rows x 4 columns]

# %%
properties_8 = properties_7[~properties_7.London_Borough.isin(nonBoroughs)]

# %%
properties_8.head()
# Out:
#        London_Borough         ID      Month  Average_price
# 0      City of London  E09000001 1995-01-01    91448.98487
# 1  Barking & Dagenham  E09000002 1995-01-01    50460.22660
# 2              Barnet  E09000003 1995-01-01    93284.51832
# 3              Bexley  E09000004 1995-01-01    64958.09036
# 4               Brent  E09000005 1995-01-01    71306.56698

# %%
pd.value_counts(properties_8['London_Borough'])
# Out:
# Lewisham                328
# Croydon                 328
# Newham                  328
# Kingston upon Thames    328
# Redbridge               328
# Enfield                 328
# City of London          328
# Islington               328
# Hounslow                328
# Waltham Forest          328
# Lambeth                 328
# Wandsworth              328
# Haringey                328
# Southwark               328
# Westminster             328
# Hammersmith & Fulham    328
# Barking & Dagenham      328
# Bexley                  328
# Havering                328
# Kensington & Chelsea    328
# Bromley                 328
# Sutton                  328
# Barnet                  328
# Richmond upon Thames    328
# Tower Hamlets           328
# Camden                  328
# Hillingdon              328
# Brent                   328
# Harrow                  328
# Greenwich               328
# Merton                  328
# Ealing                  328
# Hackney                 328
# ...

# %%
df = properties_8

# %%
df.dtypes
# Out:
# London_Borough            object
# ID                        object
# Month             datetime64[ns]
# Average_price            float64
# dtype: object

# %% [markdown]
# **2.6. Visualizing the data**
#
# To visualize the data, why not subset on a particular London Borough? Maybe do a line plot of Month against Average Price?

# %%
Harrow_prices = df[df['London_Borough'] == 'Harrow']

# %%
plot1 = Harrow_prices.plot(kind = 'line', x = 'Month', y = 'Average_price')

# %%
plot1 = Harrow_prices.plot(kind = 'line', x = 'Month', y = 'Average_price')
plot1.set_ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %% [markdown]
# To limit the number of data points you have, you might want to extract the year from every month value your *Month* column.
#
# To this end, you *could* apply a ***lambda function***. Your logic could work as follows:
# 1. look through the `Month` column
# 2. extract the year from each individual value in that column
# 3. store that corresponding year as separate column.
#
# Whether you go ahead with this is up to you. Just so long as you answer our initial brief: which boroughs of London have seen the greatest house price increase, on average, over the past two decades?

# %%
df['Year'] = df['Month'].apply(lambda x : x.year)
df.head()
# Out:
# <ipython-input-55-d626abd59e04>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Year'] = df['Month'].apply(lambda x : x.year)
#        London_Borough         ID      Month  Average_price  Year
# 0      City of London  E09000001 1995-01-01    91448.98487  1995
# 1  Barking & Dagenham  E09000002 1995-01-01    50460.22660  1995
# 2              Barnet  E09000003 1995-01-01    93284.51832  1995
# 3              Bexley  E09000004 1995-01-01    64958.09036  1995
# 4               Brent  E09000005 1995-01-01    71306.56698  1995

# %%
df.tail()
# Out:
#        London_Borough         ID      Month  Average_price  Year
# 15724          Sutton  E09000029 2022-04-01    424726.2324  2022
# 15725   Tower Hamlets  E09000030 2022-04-01    499715.8655  2022
# 15726  Waltham Forest  E09000031 2022-04-01    478260.8320  2022
# 15727      Wandsworth  E09000032 2022-04-01    641131.9851  2022
# 15728     Westminster  E09000033 2022-04-01    977553.7580  2022

# %%
df1 = df.groupby(['London_Borough','Year']).mean()

# %%
df1.head()
# Out:
#                          Average_price
# London_Borough     Year
# Barking & Dagenham 1995   51817.969390
#                    1996   51718.192690
#                    1997   55974.262309
#                    1998   60285.821083
#                    1999   65320.934441

# %%
dfg = df1.reset_index()

# %%
dfg.head()
# Out:
#        London_Borough  Year  Average_price
# 0  Barking & Dagenham  1995   51817.969390
# 1  Barking & Dagenham  1996   51718.192690
# 2  Barking & Dagenham  1997   55974.262309
# 3  Barking & Dagenham  1998   60285.821083
# 4  Barking & Dagenham  1999   65320.934441

# %%
dfg.sample(10)
# Out:
#            London_Borough  Year  Average_price
# 256               Enfield  1999   1.019870e+05
# 378              Haringey  2009   2.762141e+05
# 131               Bromley  2014   3.478572e+05
# 553  Kensington & Chelsea  2016   1.276235e+06
# 32                 Barnet  1999   1.360045e+05
# 886            Wandsworth  2013   4.574041e+05
# 4      Barking & Dagenham  1999   6.532093e+04
# 252               Enfield  1995   7.198423e+04
# 446              Havering  2021   3.907350e+05
# 284             Greenwich  1999   9.087913e+04

# %%
dfg[dfg['Year'] == max(dfg['Year'])].sort_values('Average_price', ascending = False)
# Out:
#            London_Borough  Year  Average_price
# 559  Kensington & Chelsea  2022   1.412846e+06
# 923           Westminster  2022   9.967111e+05
# 167                Camden  2022   8.604027e+05
# 195        City of London  2022   8.320157e+05
# 755  Richmond upon Thames  2022   7.663664e+05
# 363  Hammersmith & Fulham  2022   7.458604e+05
# 531             Islington  2022   7.089123e+05
# 895            Wandsworth  2022   6.317883e+05
# 335               Hackney  2022   6.241944e+05
# 391              Haringey  2022   5.917117e+05
# 55                 Barnet  2022   5.825634e+05
# 671                Merton  2022   5.626943e+05
# 615               Lambeth  2022   5.383187e+05
# 111                 Brent  2022   5.310643e+05
# 587  Kingston upon Thames  2022   5.301152e+05
# 783             Southwark  2022   5.277905e+05
# 251                Ealing  2022   5.255406e+05
# 419                Harrow  2022   5.105875e+05
# 139               Bromley  2022   4.860365e+05
# ...

# %%
dfg[dfg['Year'] == max(dfg['Year'])].sort_values('Average_price', ascending = True)
# Out:
#            London_Borough  Year  Average_price
# 27     Barking & Dagenham  2022   3.415154e+05
# 83                 Bexley  2022   3.887107e+05
# 699                Newham  2022   4.055709e+05
# 223               Croydon  2022   4.098594e+05
# 447              Havering  2022   4.133069e+05
# 811                Sutton  2022   4.235836e+05
# 307             Greenwich  2022   4.263512e+05
# 503              Hounslow  2022   4.300554e+05
# 279               Enfield  2022   4.373753e+05
# 643              Lewisham  2022   4.476689e+05
# 475            Hillingdon  2022   4.508284e+05
# 839         Tower Hamlets  2022   4.771035e+05
# 727             Redbridge  2022   4.771492e+05
# 867        Waltham Forest  2022   4.843223e+05
# 139               Bromley  2022   4.860365e+05
# 419                Harrow  2022   5.105875e+05
# 251                Ealing  2022   5.255406e+05
# 783             Southwark  2022   5.277905e+05
# 587  Kingston upon Thames  2022   5.301152e+05
# ...

# %% [markdown]
# **3. Modeling**
#
# Consider creating a function that will calculate a ratio of house prices, comparing the price of a house in 2018 to the price in 1998.
#
# Consider calling this function create_price_ratio.
#
# You'd want this function to:
# 1. Take a filter of dfg, specifically where this filter constrains the London_Borough, as an argument. For example, one admissible argument should be: dfg[dfg['London_Borough']=='Camden'].
# 2. Get the Average Price for that Borough, for the years 1998 and 2018.
# 4. Calculate the ratio of the Average Price for 1998 divided by the Average Price for 2018.
# 5. Return that ratio.
#
# Once you've written this function, you ultimately want to use it to iterate through all the unique London_Boroughs and work out the ratio capturing the difference of house prices between 1998 and 2018.
#
# Bear in mind: you don't have to write a function like this if you don't want to. If you can solve the brief otherwise, then great!
#
# ***Hint***: This section should test the skills you acquired in:
# - Python Data Science Toolbox - Part One, all modules

# %%
def create_price_ratio(b):
    """
    a function to calculate a ratio of house prices, comparing the price of a house in 2018 to the price in 1998.
    
    @param b: name of a London Borough.
    @return: ratio between average price of a house in 2018 to the average price in 1998 of b.
    """
    df1 = dfg[dfg['London_Borough'] == b]
    a = df1[df1['Year'] == 1998]['Average_price'].iloc[0]
    b = df1[df1['Year'] == 2018]['Average_price'].iloc[0]
    ratio = b/a
    return [ratio]

# %%
create_price_ratio('Bexley')
# Out:
# [4.248977046127877]

# %%
final_ratio = {}

# %%
dfg['London_Borough'].unique()
# Out:
# array(['Barking & Dagenham', 'Barnet', 'Bexley', 'Brent', 'Bromley',
#        'Camden', 'City of London', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey',
#        'Harrow', 'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth',
#        'Lewisham', 'Merton', 'Newham', 'Redbridge',
#        'Richmond upon Thames', 'Southwark', 'Sutton', 'Tower Hamlets',
#        'Waltham Forest', 'Wandsworth', 'Westminster'], dtype=object)

# %%
for x in dfg['London_Borough'].unique():
    final_ratio[x] = create_price_ratio(x)
print(final_ratio)
# Out:
# {'Barking & Dagenham': [4.89661861291754], 'Barnet': [4.358195917538044], 'Bexley': [4.248977046127877], 'Brent': [4.8945544971392865], 'Bromley': [4.0947846853338765], 'Camden': [4.935353408884261], 'City of London': [5.301620377587609], 'Croydon': [4.201100280024767], 'Ealing': [4.311450902121834], 'Enfield': [4.26347158349581], 'Greenwich': [4.763036347329193], 'Hackney': [6.198285561008662], 'Hammersmith & Fulham': [4.137798101936229], 'Haringey': [5.134624964136042], 'Harrow': [4.0591964329643195], 'Havering': [4.325230371335308], 'Hillingdon': [4.2002730803844575], 'Hounslow': [3.976409106143329], 'Islington': [4.844048012802298], 'Kensington & Chelsea': [5.082465066092464], 'Kingston upon Thames': [4.270549521484271], 'Lambeth': [4.957751163514063], 'Lewisham': [5.449221041059685], 'Merton': [4.741273313294604], 'Newham': [5.305390437201879], 'Redbridge': [4.471182006097364], 'Richmond upon Thames': [4.005161895721457], 'Southwark': [5.516485302379376], 'Sutton': [4.1185226085
# ...

# %%
df_ratio = pd.DataFrame(final_ratio)

# %%
df_ratio
# Out:
#    Barking & Dagenham    Barnet    Bexley     Brent   Bromley    Camden  \
# 0            4.896619  4.358196  4.248977  4.894554  4.094785  4.935353
#
#    City of London  Croydon    Ealing   Enfield  ...    Merton   Newham  \
# 0         5.30162   4.2011  4.311451  4.263472  ...  4.741273  5.30539
#
#    Redbridge  Richmond upon Thames  Southwark    Sutton  Tower Hamlets  \
# 0   4.471182              4.005162   5.516485  4.118523       4.626701
#
#    Waltham Forest  Wandsworth  Westminster
# 0        5.834756    4.757709     5.353565
#
# [1 rows x 33 columns]

# %%
df_ratio_transpose = df_ratio.T
df_ratio = df_ratio_transpose.reset_index()

# %%
df_ratio.head()
# Out:
#                 index         0
# 0  Barking & Dagenham  4.896619
# 1              Barnet  4.358196
# 2              Bexley  4.248977
# 3               Brent  4.894554
# 4             Bromley  4.094785

# %%
df_ratio.rename(columns={'index':'London_Borough',0:'2018/1998'}, inplace = True)

# %%
df_ratio.head()
# Out:
#        London_Borough  2018/1998
# 0  Barking & Dagenham   4.896619
# 1              Barnet   4.358196
# 2              Bexley   4.248977
# 3               Brent   4.894554
# 4             Bromley   4.094785

# %%
top10 = df_ratio.sort_values(by = '2018/1998', ascending = False).head(10)
print(top10)
# Out:
#           London_Borough  2018/1998
# 11               Hackney   6.198286
# 30        Waltham Forest   5.834756
# 27             Southwark   5.516485
# 22              Lewisham   5.449221
# 32           Westminster   5.353565
# 24                Newham   5.305390
# 6         City of London   5.301620
# 13              Haringey   5.134625
# 19  Kensington & Chelsea   5.082465
# 21               Lambeth   4.957751

# %%
graph = top10[['London_Borough','2018/1998']].plot(kind = 'bar')
graph.set_xticklabels(top10.London_Borough)
# Out:
# [Text(0, 0, 'Hackney'),
#  Text(1, 0, 'Waltham Forest'),
#  Text(2, 0, 'Southwark'),
#  Text(3, 0, 'Lewisham'),
#  Text(4, 0, 'Westminster'),
#  Text(5, 0, 'Newham'),
#  Text(6, 0, 'City of London'),
#  Text(7, 0, 'Haringey'),
#  Text(8, 0, 'Kensington & Chelsea'),
#  Text(9, 0, 'Lambeth')]

# %%
bottom10 = df_ratio.sort_values(by = '2018/1998', ascending = True).head(10)
print(bottom10)
# Out:
#           London_Borough  2018/1998
# 17              Hounslow   3.976409
# 26  Richmond upon Thames   4.005162
# 14                Harrow   4.059196
# 4                Bromley   4.094785
# 28                Sutton   4.118523
# 12  Hammersmith & Fulham   4.137798
# 16            Hillingdon   4.200273
# 7                Croydon   4.201100
# 2                 Bexley   4.248977
# 9                Enfield   4.263472

# %%
graph = bottom10[['London_Borough','2018/1998']].plot(kind = 'bar')
graph.set_xticklabels(bottom10.London_Borough)
# Out:
# [Text(0, 0, 'Hounslow'),
#  Text(1, 0, 'Richmond upon Thames'),
#  Text(2, 0, 'Harrow'),
#  Text(3, 0, 'Bromley'),
#  Text(4, 0, 'Sutton'),
#  Text(5, 0, 'Hammersmith & Fulham'),
#  Text(6, 0, 'Hillingdon'),
#  Text(7, 0, 'Croydon'),
#  Text(8, 0, 'Bexley'),
#  Text(9, 0, 'Enfield')]

# %%
df_Borough = df_ratio.sort_values(by = '2018/1998', ascending = False)
print(df_Borough)
# Out:
#           London_Borough  2018/1998
# 11               Hackney   6.198286
# 30        Waltham Forest   5.834756
# 27             Southwark   5.516485
# 22              Lewisham   5.449221
# 32           Westminster   5.353565
# 24                Newham   5.305390
# 6         City of London   5.301620
# 13              Haringey   5.134625
# 19  Kensington & Chelsea   5.082465
# 21               Lambeth   4.957751
# 5                 Camden   4.935353
# 0     Barking & Dagenham   4.896619
# 3                  Brent   4.894554
# 18             Islington   4.844048
# 10             Greenwich   4.763036
# 31            Wandsworth   4.757709
# 23                Merton   4.741273
# 29         Tower Hamlets   4.626701
# 25             Redbridge   4.471182
# 1                 Barnet   4.358196
# 15              Havering   4.325230
# 8                 Ealing   4.311451
# 20  Kingston upon Thames   4.270550
# 9                Enfield   4.263472
# 2                 Bexley   4.248977
# ...

# %%
graph = df_Borough[['London_Borough','2018/1998']].plot(kind = 'bar')
graph.set_xticklabels(df_Borough.London_Borough)
# Out:
# [Text(0, 0, 'Hackney'),
#  Text(1, 0, 'Waltham Forest'),
#  Text(2, 0, 'Southwark'),
#  Text(3, 0, 'Lewisham'),
#  Text(4, 0, 'Westminster'),
#  Text(5, 0, 'Newham'),
#  Text(6, 0, 'City of London'),
#  Text(7, 0, 'Haringey'),
#  Text(8, 0, 'Kensington & Chelsea'),
#  Text(9, 0, 'Lambeth'),
#  Text(10, 0, 'Camden'),
#  Text(11, 0, 'Barking & Dagenham'),
#  Text(12, 0, 'Brent'),
#  Text(13, 0, 'Islington'),
#  Text(14, 0, 'Greenwich'),
#  Text(15, 0, 'Wandsworth'),
#  Text(16, 0, 'Merton'),
#  Text(17, 0, 'Tower Hamlets'),
#  Text(18, 0, 'Redbridge'),
#  Text(19, 0, 'Barnet'),
#  Text(20, 0, 'Havering'),
#  Text(21, 0, 'Ealing'),
#  Text(22, 0, 'Kingston upon Thames'),
#  Text(23, 0, 'Enfield'),
#  Text(24, 0, 'Bexley'),
#  Text(25, 0, 'Croydon'),
#  Text(26, 0, 'Hillingdon'),
#  Text(27, 0, 'Hammersmith & Fulham'),
#  Text(28, 0, 'Sutton'),
#  Text(29, 0, 'Bromley'),
#  Text(30, 0, 'Harrow'),
#  Text(31, 0, 'Richmond upon Thames'),
#  Text(32, 0, 'Hounslow')]

# %% [markdown]
# ### 4. Conclusion

# %% [markdown]
# # Conclusion on London Housing
#
# The goal of this study was to find out which Boroughs of London have seen the greatest increase in housing prices, on average, over the last two decades. According to the data, we can see that the average housing price of Hackney has multiplied by approximately six times over that period.
#
# Some other Boroughs that have seen high increases in average housing prices are Waltham Forest, Southwark, Lewisham, Westminster, Newham, City of London, Haringey etc.
#
# We could also see which Borough has the lowest increase in housing prices on average. According to the dataframe, Hounslow has the lowest increase. The average housing price increased by approximately 4 times.
#
# Also, we can see that all the Boroughs have seen an increase in the average housing price by at least 4 times.
#
# Next, we notice that in the year 2022, the most expensive Borough for housing is Kensington and Chelsea followed by Westminster and Camden. On the other hand, the least expensive Borough for housing is Barking and Dagenham followed by Bexley, Newham and Croydon.
#
# An in-depth exploratory analysis could be done to find out the various factors contributing to the increase seen in the average housing price in the Boroughs, if we were provided with data of other related variables. That might be appropriate next step to do in this project.
